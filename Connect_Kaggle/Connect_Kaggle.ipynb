# %% [markdown]
# # To connect my kaggle account via my json file

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %% [markdown]
# # Download dataset from kaggle via API link

# %%
# !kaggle datasets download -d seanangelonathanael/dataset-cybercrime-in-india
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading dataset-cybercrime-in-india.zip to /content
#   0% 0.00/4.18k [00:00<?, ?B/s]
# 100% 4.18k/4.18k [00:00<00:00, 10.0MB/s]

# %% [markdown]
# # Unzip a dataset

# %%
import zipfile
zip_ref = zipfile.ZipFile('dataset-cybercrime-in-india.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# # Import numpy and pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Create a Panda variable to load the csv file

# %%
df=pd.read_csv("/content/placement.csv")

# %% [markdown]
# # To see the dataset

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# # To see the shape of the tensor

# %%
df.shape
# Out:
# (100, 4)

# %%
# Steps
## 0. Preproces + EDA + Feature Selection
## 1. Extract input and output cols
## 2. Scale the values
## 3. Train test split
## 4. Train the model
## 5. Evaluate the model/model selection
## 6. Deploy the model

# %% [markdown]
# # To see if there is missing values or unwanted column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %% [markdown]
# # **PREPROCESSING**

# %% [markdown]
# # Column from 1 to onward, deleting column 0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# # **EDA**

# %% [markdown]
# # Import graphing or ploting library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Ploting the inputs in graph and c for color in the output

# %%
plt.scatter(df["cgpa"],df["iq"],c=df["placement"])

# %% [markdown]
# # Separating input and output, column 0 and 1

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 23   4.7   87.0
# 33   6.0  149.0
# 81   5.4  107.0
# 37   8.1  149.0
# 50   3.5  233.0
# ..   ...    ...
# 74   6.7  154.0
# 6    5.7  143.0
# 24   4.7  121.0
# 39   4.6  146.0
# 94   4.7   52.0
#
# [90 rows x 2 columns]

# %% [markdown]
# # **SCALLING**

# %% [markdown]
# # Import scaller

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.13899193, -0.99825275],
#        [ 0.0068555 ,  0.5900707 ],
#        [-0.52199716, -0.48589034],
#        [ 1.8578398 ,  0.5900707 ],
#        [-2.19669724,  2.74199279],
#        [ 0.09499761,  0.76939754],
#        [-0.78642349, -1.53623327],
#        [ 1.32898714,  0.82063378],
#        [ 1.15270292, -1.02387087],
#        [-0.25757083,  0.15456266],
#        [ 0.80013448, -0.76768967],
#        [-0.69828138,  0.15456266],
#        [-0.69828138,  2.51142971],
#        [-0.96270771,  0.2057989 ],
#        [ 0.0068555 , -1.53623327],
#        [ 2.03412402,  1.07681498],
#        [ 1.32898714,  0.10332642],
#        [-0.96270771, -0.15285478],
#        [ 0.71199237, -0.35779974],
#        [-0.61013927, -0.12723666],
#        [-0.78642349,  0.05209018],
#        [ 1.76969769, -1.20319771],
#        [-0.8745656 , -0.89578027],
#        [-1.05084982, -0.35779974],
#        [-0.69828138, -0.40903598],
#        [ 0.44756605, -0.92139839],
#        [-0.96270771,  0.64130694],
#        [ 0.71199237, -0.07600042],
#        [-0.96270771,  1.79412235],
#        [ 0.27128183,  0.02647206],
#        [ 0.88827659, -0.35779974],
#        [ 0.53570816,  0.30827138],
#        [-0.69828138, -0.92139839],
#        [ 0.53570816, -0.15285478],
#        [ 0.9764187 ,  0.64130694],
#        [-1.49156037,  1.89659483],
#        [-0.96270771,  0.74377942],
#        [ 0.62385026,  1.43546866],
#        [ 1.15270292, -1.94612319],
#        [ 0.09499761, -0.58836283],
#        [-1.7559867 , -1.30567019],
#        [ 0.27128183,  0.05209018],
#        [ 0.88827659,  0.3338895 ],
#        [-1.7559867 , -0.66521719],
#        [ 0.18313972, -0.33218162],
#        [-0.8745656 , -0.20409102],
#        [-0.16942872,  1.02557874],
#        [ 0.0068555 , -2.07421379],
#        [ 0.09499761, -1.56185139],
#        [ 0.71199237, -0.92139839],
#        [ 0.44756605,  0.87187002],
#        [-1.8441288 , -0.4346541 ],
#        [ 1.41712925, -0.94701651],
#        [-0.78642349,  1.28175994],
#        [ 0.09499761,  0.15456266],
#        [ 1.24084503,  0.15456266],
#        [-0.16942872,  0.41074386],
#        [ 0.44756605,  0.10332642],
#        [ 0.80013448,  0.3338895 ],
#        [-1.05084982,  1.1024331 ],
#        [-1.40341826,  0.5900707 ],
#        [ 0.88827659,  1.87097671],
#        [ 0.09499761, -1.15196147],
#        [-0.69828138,  0.89748814],
#        [ 0.44756605, -2.27915875],
#        [ 0.0068555 , -0.61398095],
#        [-0.08128661, -0.51150847],
#        [ 0.27128183, -0.58836283],
#        [ 0.71199237,  0.38512574],
#        [ 0.88827659, -1.58746951],
#        [ 0.35942394,  0.38512574],
#        [-0.52199716, -0.3065635 ],
#        [-0.25757083,  1.1024331 ],
#        [ 2.21040824, -0.15285478],
#        [-0.52199716,  0.23141702],
#        [ 0.88827659,  1.25614182],
#        [ 0.80013448,  0.30827138],
#        [ 1.41712925,  0.05209018],
#        [-1.05084982,  0.38512574],
#        [ 1.15270292, -0.25532726],
#        [ 0.9764187 , -1.99735943],
#        [-0.52199716,  0.3338895 ],
#        [-0.61013927, -0.3065635 ],
#        [-2.37298146,  1.46108678],
#        [ 1.8578398 ,  1.02557874],
#        [ 0.62385026,  0.7181613 ],
#        [-0.25757083,  0.43636198],
#        [-1.13899193, -0.12723666],
#        [-1.22713404,  0.51321634],
#        [-1.13899193, -1.89488695]])

# %% [markdown]
# # Already trained so don't need to use fit_transform

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.15270292,  0.28265326],
#        [-0.8745656 , -1.61308763],
#        [ 1.32898714, -1.66432387],
#        [ 0.35942394, -0.25532726],
#        [-0.25757083,  0.35950762],
#        [ 0.0068555 , -0.0503823 ],
#        [-0.96270771, -1.66432387],
#        [-1.05084982,  0.94872438],
#        [-1.40341826, -2.15106815],
#        [ 1.59341347, -0.3065635 ]])

# %% [markdown]
# # **TRAINING**

# %% [markdown]
# # Import ML model "Logistic Regression"

# %%
from sklearn.linear_model import LogisticRegression

# %%
mdl = LogisticRegression()

# %% [markdown]
# # Train the model

# %%
mdl.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **EVALUATE**

# %% [markdown]
# # Passing new data for testing the accuracy

# %%
Y_pred = mdl.predict(X_test)

# %%
Y_test
# Out:
# 61    1
# 7     0
# 44    1
# 13    1
# 36    0
# 27    1
# 73    0
# 34    0
# 96    0
# 55    1
# Name: placement, dtype: int64

# %% [markdown]
# # Import library for accuracy

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Finding accuracy

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.9

# %% [markdown]
# # **PLOTING THE DECISSION BOUNDRY**

# %% [markdown]
# # Import mlxtend ploting library

# %%
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# # .values to convert and X_train is already a numpy array because of scalling

# %%
plot_decision_regions(X_train, Y_train.values, clf=mdl, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# # **DEPLOY**

# %% [markdown]
# # Converting object into file

# %%
import pickle
pickle.dump(mdl, open("test.pkl", "wb"))
