# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanNihal/Machine_Learning/blob/main/working_with_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Read from a local file

# %%
pd.read_csv("placement.csv")
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# # Read using url

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # Tab separated file or .tsv

# %%
pd.read_csv("sample-1.tsv", sep="\t")
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN    JANUARY        NaN        NaN        NaN        NaN
# 1          NaN          S          M          T          W          T
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN          2          3          4          5          6
# 4          NaN          9         10         11         12         13
# 5          NaN         16         17         18         19         20
# 6          NaN         23         24         25         26         27
# 7          NaN         30         31        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN     APRIL         NaN        NaN        NaN        NaN
# 10         NaN          S          M          T          W          T
# 11         NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# # To add column name

# %%
pd.read_csv("placement.csv", names=["I", "C", "R", "P"])
# Out:
#         I     C      R          P
# 0     NaN  cgpa     iq  placement
# 1     0.0   6.8  123.0          1
# 2     1.0   5.9  106.0          0
# 3     2.0   5.3  121.0          0
# 4     3.0   7.4  132.0          1
# ..    ...   ...    ...        ...
# 96   95.0   4.3  200.0          0
# 97   96.0   4.4   42.0          0
# 98   97.0   6.7  182.0          1
# 99   98.0   6.3  103.0          1
# 100  99.0   6.2  113.0          1
#
# [101 rows x 4 columns]

# %% [markdown]
# # To turn a column as index

# %%
pd.read_csv("placement.csv", names=["I", "C", "R", "P"], index_col="I")
# Out:
#          C      R          P
# I
# NaN   cgpa     iq  placement
# 0.0    6.8  123.0          1
# 1.0    5.9  106.0          0
# 2.0    5.3  121.0          0
# 3.0    7.4  132.0          1
# ...    ...    ...        ...
# 95.0   4.3  200.0          0
# 96.0   4.4   42.0          0
# 97.0   6.7  182.0          1
# 98.0   6.3  103.0          1
# 99.0   6.2  113.0          1
#
# [101 rows x 3 columns]

# %% [markdown]
# # Turn 1st column into header

# %%
pd.read_csv("sample-1.tsv", sep="\t", header=1)
# Out:
#     Unnamed: 0  JANUARY Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN        S          M          T          W          T
# 1          NaN      NaN        NaN        NaN        NaN        NaN
# 2          NaN        2          3          4          5          6
# 3          NaN        9         10         11         12         13
# 4          NaN       16         17         18         19         20
# 5          NaN       23         24         25         26         27
# 6          NaN       30         31        NaN        NaN        NaN
# 7          NaN      NaN        NaN        NaN        NaN        NaN
# 8          NaN   APRIL         NaN        NaN        NaN        NaN
# 9          NaN        S          M          T          W          T
# 10         NaN      NaN        NaN        NaN        NaN        NaN
# 11         NaN        3          4          5          6          7
# 12         NaN       10         11         12         13         14
# ...

# %% [markdown]
# # Use specific columns

# %%
pd.read_csv("placement.csv", usecols=["cgpa", "iq"])
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %% [markdown]
# # For single colums and squeeze to make it a series object not data frame

# %%
pd.read_csv("placement.csv", usecols=["cgpa"], squeeze=True)
# Out:
# <ipython-input-33-a9614ec683a5>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv("placement.csv", usecols=["cgpa"], squeeze=True)
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %% [markdown]
# # Skiprows/nrows Parameter
# Line numbers to skip (0-indexed) or number of lines to skip (int) at the start of the file. If callable, the callable function will be evaluated against the row indices, returning True if the row should be skipped and False otherwise. An example Of a valid callable argument would be Lambda x: x in [0,2].

# %%
pd.read_csv("placement.csv", skiprows=[1,4])
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            1   5.9  106.0          0
# 1            2   5.3  121.0          0
# 2            4   5.8  142.0          0
# 3            5   7.1   48.0          1
# 4            6   5.7  143.0          0
# ..         ...   ...    ...        ...
# 93          95   4.3  200.0          0
# 94          96   4.4   42.0          0
# 95          97   6.7  182.0          1
# 96          98   6.3  103.0          1
# 97          99   6.2  113.0          1
#
# [98 rows x 4 columns]

# %%
pd.read_csv("placement.csv", nrows=10)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# 5           5   7.1   48.0          1
# 6           6   5.7  143.0          0
# 7           7   5.0   63.0          0
# 8           8   6.1  156.0          0
# 9           9   5.1   66.0          0

# %% [markdown]
# # Encoding parameter not utf 8
# UnicodeDecodeError

# %%
pd.read_csv("zomato.csv", encoding="latin-1")
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # Column different in different rows, bad lines

# %%
pd.read_csv("zomato.csv", encoding="latin-1", error_bad_lines=False)
# Out:
# <ipython-input-7-f2bf536ed9d1>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   pd.read_csv("zomato.csv", encoding="latin-1", error_bad_lines=False)
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# ...

# %% [markdown]
# # Change Data type

# %%
pd.read_csv("aug_train.csv", dtype={"target":int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %% [markdown]
# # Date handling
# default string so need to convert into date time formate

# %%
pd.read_csv("IPL Matches 2008-2020.csv", parse_dates=["date"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # Converters

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
pd.read_csv("IPL Matches 2008-2020.csv",converters={"team1":rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Change a columns value NaN

# %%
pd.read_csv("aug_train.csv",na_values=["Male"])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Loading a huge dataset in chunks
# if the data set is to large then we can divide into chunks and then can access them using loop

# %%
dfs = pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
