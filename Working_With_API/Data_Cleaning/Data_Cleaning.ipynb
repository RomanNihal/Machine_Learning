# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/tmdb_popular_movies.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18850 entries, 0 to 18849
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18850 non-null  int64
#  1   id            18850 non-null  int64
#  2   title         18850 non-null  object
#  3   overview      18850 non-null  object
#  4   release_date  18849 non-null  object
#  5   popularity    18849 non-null  float64
#  6   vote_average  18849 non-null  float64
#  7   vote_count    18849 non-null  float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18850 entries, 0 to 18849
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            18850 non-null  int64
#  1   title         18850 non-null  object
#  2   overview      18850 non-null  object
#  3   release_date  18849 non-null  object
#  4   popularity    18849 non-null  float64
#  5   vote_average  18849 non-null  float64
#  6   vote_count    18849 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.0+ MB

# %%
df = df.drop_duplicates(subset=['title'], keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11965 entries, 0 to 17949
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            11965 non-null  int64
#  1   title         11965 non-null  object
#  2   overview      11965 non-null  object
#  3   release_date  11965 non-null  object
#  4   popularity    11965 non-null  float64
#  5   vote_average  11965 non-null  float64
#  6   vote_count    11965 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 747.8+ KB

# %%
df = df.dropna()

# %%
df.to_csv('tmdb_popular_movies.csv', index=False)
