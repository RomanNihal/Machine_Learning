# %%
import pandas as pd

# %%
df = pd.read_csv('tmdb_upcoming_movies.csv', engine='python', on_bad_lines='skip')

# %%
df
# Out:
#       Unnamed: 0       id                     title  \
# 0              0      278  The Shawshank Redemption
# 1              1      238             The Godfather
# 2              2      240     The Godfather Part II
# 3              3      424          Schindler's List
# 4              4      389              12 Angry Men
# ...          ...      ...                       ...
# 21438      21436  1388433            Operation Cold
# 21439      21437  1388373           Blend-a-Vampire
# 21440      21438  1388352       Lettera alla natura
# 21441      21439  1388330                    Anomia
# 21442      21440  1388322                   Devwani
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
df.dropna(inplace=True)

# %%
df.to_csv('tmdb_upcoming_movies_cleaned.csv', index=False)

# %%
df = pd.read_csv('tmdb_upcoming_movies_cleaned.csv')

# %%
df
# Out:
#        Unnamed: 0       id                     title  \
# 0               0      278  The Shawshank Redemption
# 1               1      238             The Godfather
# 2               2      240     The Godfather Part II
# 3               3      424          Schindler's List
# 4               4      389              12 Angry Men
# ...           ...      ...                       ...
# 20648       21435  1388437     It's My Damn Business
# 20649       21436  1388433            Operation Cold
# 20650       21437  1388373           Blend-a-Vampire
# 20651       21439  1388330                    Anomia
# 20652       21440  1388322                   Devwani
#
#                                                 overview release_date  \
# 0      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# ...
