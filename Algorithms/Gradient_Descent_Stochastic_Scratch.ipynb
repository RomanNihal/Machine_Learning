# %% [markdown]
# # **Linear Regression**

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_diabetes
X, y = load_diabetes(return_X_y=True)

print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %% [markdown]
# # **MY Class**

# %%
class MyGD_Stochastic:
  def __init__(self, lRate=0.01, epochs=100):
    self.coef_ = None
    self.intercept_ = None
    self.lRate = lRate
    self.epochs = epochs

  def fit(self, X_train, y_train):
    self.intercept_ = 0
    self.coef_ = np.ones(X_train.shape[1])

    for i in range(self.epochs):
      for j in range(X_train.shape[0]):
        idx = np.random.randint(0, X_train.shape[0])
        y_hat = np.dot(X_train[idx], self.coef_) + self.intercept_

        intercept_der = -2 * (y_train[idx] - y_hat)
        self.intercept_ = self.intercept_ - (self.lRate * intercept_der)

        coef_der = -2 * np.dot((y_train[idx] - y_hat), X_train[idx])
        self.coef_ = self.coef_ - (self.lRate * coef_der)

    print(self.coef_)
    print(self.intercept_)

  def predict(self, X_test):
    return np.dot(X_test, self.coef_) + self.intercept_

# %%
gd = MyGD_Stochastic(epochs=100, lRate=0.1)

import time
start = time.time()

gd.fit(X_train, y_train)

print(time.time() - start)
# Out:
# [  -3.90214836 -205.0417887   506.25498685  351.19607021 -143.95443438
#   -50.24167216 -171.85844763   73.50059563  559.56527086   33.65994506]
# 158.93434827332877
# 0.6313323974609375

# %%
y_pred = gd.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.43993467814757403

# %% [markdown]
# **Compare with Batch GD**
# " https://colab.research.google.com/drive/1AGUZeo0mjpL1PpDa_iL_AIyAjY8zXWhy?usp=sharing "

# %% [markdown]
# # **SGD Regressor**

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor(max_iter=100, learning_rate='constant', eta0=0.1)
sgd.fit(X_train, y_train)
# Out:
# SGDRegressor(eta0=0.1, learning_rate='constant', max_iter=100)

# %%
y_pred = gd.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.43993467814757403
